# %% [markdown]
# # Fully Convolutional Networks & Transfer Learning

# %%
# !pip install -U d2l
# Out:
# Requirement already satisfied: d2l in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (0.17.0)
# Requirement already satisfied: requests in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from d2l) (2.25.1)
# Requirement already satisfied: matplotlib in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from d2l) (3.4.2)
# Requirement already satisfied: jupyter in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from d2l) (1.0.0)
# Requirement already satisfied: pandas in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from d2l) (1.2.4)
# Requirement already satisfied: numpy in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from d2l) (1.20.3)
# Requirement already satisfied: jupyter-console in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (6.4.0)
# Requirement already satisfied: nbconvert in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (6.0.7)
# Requirement already satisfied: ipykernel in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (5.3.4)
# Requirement already satisfied: ipywidgets in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (7.6.4)
# Requirement already satisfied: qtconsole in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (5.0.3)
# Requirement already satisfied: notebook in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter->d2l) (6.4.0)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipykernel->jupyter->d2l) (7.22.0)
# Requirement already satisfied: jupyter-client in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipykernel->jupyter->d2l) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipykernel->jupyter->d2l) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipykernel->jupyter->d2l) (5.0.5)
# Requirement already satisfied: pygments in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (2.9.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (0.17.2)
# Requirement already satisfied: colorama in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (0.7.5)
# Requirement already satisfied: backcall in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (0.2.0)
# Requirement already satisfied: decorator in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->d2l) (5.0.9)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->d2l) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->jupyter->d2l) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter->d2l) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipywidgets->jupyter->d2l) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipywidgets->jupyter->d2l) (1.0.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from ipywidgets->jupyter->d2l) (5.1.3)
# Requirement already satisfied: jupyter-core in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->d2l) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (0.17.3)
# Requirement already satisfied: argon2-cffi in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (0.9.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (20.0.0)
# Requirement already satisfied: jinja2 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from notebook->jupyter->d2l) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter-client->ipykernel->jupyter->d2l) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->jupyter->d2l) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->d2l) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from argon2-cffi->notebook->jupyter->d2l) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->d2l) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from jinja2->notebook->jupyter->d2l) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from matplotlib->d2l) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from matplotlib->d2l) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from matplotlib->d2l) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from matplotlib->d2l) (8.2.0)
# Requirement already satisfied: testpath in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.4.4)
# Requirement already satisfied: bleach in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbconvert->jupyter->d2l) (0.3)
# Requirement already satisfied: nest-asyncio in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->d2l) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->d2l) (1.10)
# Requirement already satisfied: packaging in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from bleach->nbconvert->jupyter->d2l) (20.9)
# Requirement already satisfied: webencodings in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from bleach->nbconvert->jupyter->d2l) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from pandas->d2l) (2021.1)
# Requirement already satisfied: qtpy in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from qtconsole->jupyter->d2l) (1.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from requests->d2l) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from requests->d2l) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from requests->d2l) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gs70055\anaconda3\envs\su\lib\site-packages (from requests->d2l) (2020.12.5)

# %%
# %matplotlib inline
import torch
import torchvision
from torch import nn
from torch.nn import functional as F
from d2l import torch as d2l
import os

# %% [markdown]
# ## Dataset
# Pascal VOC2012 dataset contains 20 classes.
#
# The train/val data has 11,530 images containing 27,450 ROI annotated objects and 6,929 segmentations.

# %%
#d2l.DATA_HUB['voc2012'] = (d2l.DATA_URL + 'VOCtrainval_11-May-2012.tar',
#                           '4e443f8a2eca6b1dac8a6c57641b67dd40621a49')

voc_dir = d2l.download_extract('voc2012', 'VOCdevkit/VOC2012')

# %%
def read_voc_images(voc_dir, is_train=True):
    """Read all VOC feature and label images."""
    txt_fname = os.path.join(voc_dir, 'ImageSets', 'Segmentation',
                             'train.txt' if is_train else 'val.txt')
    mode = torchvision.io.image.ImageReadMode.RGB
    with open(txt_fname, 'r') as f:
        images = f.read().split()
    features, labels = [], []
    for i, fname in enumerate(images):
        features.append(
            torchvision.io.read_image(
                os.path.join(voc_dir, 'JPEGImages', f'{fname}.jpg')))
        labels.append(
            torchvision.io.read_image(
                os.path.join(voc_dir, 'SegmentationClass', f'{fname}.png'),
                mode))
    return features, labels

train_features, train_labels = read_voc_images(voc_dir, True)

# %%
#show the first five input images and their labels. 
#In the label images, white and black represent borders and background, respectively,
#while the other colors correspond to different classes.
n = 5
imgs = train_features[0:n] + train_labels[0:n]
imgs = [img.permute(1, 2, 0) for img in imgs]
d2l.show_images(imgs, 2, n);

# %% [markdown]
# ## Construct FCN using ResNet-18 as backbone

# %%
pretrained_net = torchvision.models.resnet18(pretrained=True)
list(pretrained_net.children())[-3:]    #showing the last three items in the list
# Out:
# [Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (downsample): Sequential(
#        (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#        (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  AdaptiveAvgPool2d(output_size=(1, 1)),
#  Linear(in_features=512, out_features=1000, bias=True)]

# %% [markdown]
# ## Create fully convolutional network, which copies all the pretrained layers in the ResNet-18 except the last two layers: final global average pooling layer and the fully-connected layer.

# %%
net = nn.Sequential(*list(pretrained_net.children())[:-2])
list(net.children())[-3:]
# Out:
# [Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (downsample): Sequential(
#        (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#        (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (downsample): Sequential(
#        (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#        (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (downsample): Sequential(
#        (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#        (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  )]

# %% [markdown]
# ## Given an input with height and width of 320 and 480 respectively, the forward propagation of net reduces the input height and width to 1/32 of the original, namely 10 and 15.

# %%
X = torch.rand(size=(1, 3, 320, 480))

# %%
net(X).shape
# Out:
# torch.Size([1, 512, 10, 15])

# %% [markdown]
# Next, we use a  1×1  convolutional layer to transform the number of output channels into the number of classes (21) of the Pascal VOC2012 dataset, including the negative background class. Finally, we need to increase the height and width of the feature maps by 32 times to change them back to the height and width of the input image.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Long et al., 2015](https://arxiv.org/abs/1411.4038)
#
# Recall how to calculate the output shape of a convolutional layer. Since (320−64+16×2+32)/32=10  and  (480−64+16×2+32)/32=15 , we construct a transposed convolutional layer with stride of  32 , setting the height and width of the kernel to  32*2 = 64, the padding to  32/2 = 16.
#
# In general, we can see that for stride  s , padding  s/2  (assuming  s/2  is an integer), and the height and width of the kernel  2s , the transposed convolution will increase the height and width of the input by  s  times.

# %%
num_classes = 21
net.add_module('final_conv', nn.Conv2d(512, num_classes, kernel_size=1))
net.add_module(
    'transpose_conv',
    nn.ConvTranspose2d(num_classes, num_classes, kernel_size=64, padding=16,
                       stride=32))

# %%
list(net.children())[-3:]
# Out:
# [Sequential(
#    (0): BasicBlock(
#      (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (downsample): Sequential(
#        (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#        (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (1): BasicBlock(
#      (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1)),
#  ConvTranspose2d(21, 21, kernel_size=(64, 64), stride=(32, 32), padding=(16, 16))]

# %%
net(X).shape
# Out:
# torch.Size([1, 21, 320, 480])

# %% [markdown]
# ## Next, we will intialize the weights for the transposed layer using bilinear interpolation. First, let us see how the bilinear interpolation works.
#
# ### Bilinear Interpoliation for initializing transposed covolutional layers
# Bilinear interpolation is one of the commonly used upsampling techniques. It is also often used for initializing transposed convolutional layers.
#
# The bilinear interpolant is not linear; but it is linear (i.e. affine) along lines parallel to either the x or the y direction, equivalently if x or y is held constant. Along any other straight line, the interpolant is quadratic.
# https://en.wikipedia.org/wiki/Bilinear_interpolation

# %%
def bilinear_kernel(in_channels, out_channels, kernel_size):
    factor = (kernel_size + 1) // 2
    if kernel_size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = (torch.arange(kernel_size).reshape(-1, 1),
          torch.arange(kernel_size).reshape(1, -1))
    filt = (1 - torch.abs(og[0] - center) / factor) * \
           (1 - torch.abs(og[1] - center) / factor)
    weight = torch.zeros(
        (in_channels, out_channels, kernel_size, kernel_size))
    weight[range(in_channels), range(out_channels), :, :] = filt
    return weight

# %% [markdown]
# We construct a transposed convolutional layer that doubles the height and weight, and initialize its kernel with the bilinear_kernel function.

# %%
conv_trans = nn.ConvTranspose2d(3, 3, kernel_size=4, padding=1, stride=2,
                                bias=False)
conv_trans.weight.data.copy_(bilinear_kernel(3, 3, 4));

# %% [markdown]
# Read the image X and assign the upsampling output to Y. In order to print the image, we need to adjust the position of the channel dimension.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E6A-8E75
#
#  Directory of C:\Users\gs70055\DeepLearning2021
#
# 10/01/2021  03:31 PM    <DIR>          .
# 10/01/2021  03:31 PM    <DIR>          ..
# 10/01/2021  03:31 PM    <DIR>          .ipynb_checkpoints
# 09/07/2021  05:21 PM           827,091 1_Introduction.pdf
# 09/07/2021  05:21 PM         1,299,708 2_BackPropagation.pdf
# 09/07/2021  05:21 PM         1,673,875 3_ConNets.pdf
# 09/25/2021  10:42 AM           805,258 4b_SE_SepConv.pdf
# 09/25/2021  10:42 AM         5,758,963 4_Modern_ConvNets.pdf
# 09/25/2021  10:42 AM         3,329,411 5_Object_Detection.pdf
# 09/28/2021  07:12 PM         2,464,129 6_Segmentation.pdf
# 09/28/2021  07:12 PM           535,148 7_Transfer_Learning.pdf
# 09/07/2021  06:03 PM            10,723 Assignment_1.ipynb
# 09/29/2021  02:08 PM           972,528 Assignment_2.ipynb
# 10/01/2021  03:31 PM           671,804 Assignment_3.ipynb
# 06/04/2009  04:47 PM    <DIR>          cifar-10-batches-py
# 09/07/2021  07:08 PM       170,498,071 cifar-10-python.tar.gz
# 09/26/2021  10:29 AM    <DIR>          data
# 08/31/2021  05:37 PM            30,210 NB1_Introduction.ipynb
# 09/04/2021  10:42 PM             5,881 NB2_Autograd.ipynb
# 08/31/2021  07:52 PM            15,306 NB3_Network_Construction.ipynb
# 09/25/2021  03:32 PM           106,426 NB4_Training_Example.ipynb
# 09/25/2021  03:43 PM           144,233 NB5_ConvNets.ipynb
# 09/25/2021  04:37 PM           545,599 NB6_ModernCNNs.ipynb
# 10/01/2021  03:31 PM           187,602 NB7_FCN.ipynb
#               19 File(s)    189,881,966 bytes
#                5 Dir(s)  838,835,646,464 bytes free

# %%
img = torchvision.transforms.ToTensor()(d2l.Image.open('/content/drive/MyDrive/d2l_pytorch/img/catdog.jpg'))
X = img.unsqueeze(0)
Y = conv_trans(X)
out_img = Y[0].permute(1, 2, 0).detach()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-45eee8e85ad4> in <module>
# ----> 1 img = torchvision.transforms.ToTensor()(d2l.Image.open('/content/drive/MyDrive/d2l_pytorch/img/catdog.jpg'))
#       2 X = img.unsqueeze(0)
#       3 Y = conv_trans(X)
#       4 out_img = Y[0].permute(1, 2, 0).detach()
#
# ~\Anaconda3\envs\su\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/d2l_pytorch/img/catdog.jpg'

# %% [markdown]
# As we can see, the transposed convolutional layer increases both the height and width of the image by a factor of two. Except for the different scales in coordinates, the image scaled up by bilinear interpolation and the original image printed in Section 13.3 look the same.

# %%
d2l.set_figsize()
print('input image shape:', img.permute(1, 2, 0).shape)
d2l.plt.imshow(img.permute(1, 2, 0))
print('output image shape:', out_img.shape)
d2l.plt.imshow(out_img);

# %% [markdown]
# ## Initialize the transposed convolutional layer with upsampling of bilinear interpolation and Train and Test the previously constructed FCN.

# %%
W = bilinear_kernel(num_classes, num_classes, 64)
net.transpose_conv.weight.data.copy_(W)
# Out:
# tensor([[[[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]],
#
#          ...,
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         ...,
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           ...,
#           [0.0012, 0.0037, 0.0061,  ..., 0.0061, 0.0037, 0.0012],
#           [0.0007, 0.0022, 0.0037,  ..., 0.0037, 0.0022, 0.0007],
#           [0.0002, 0.0007, 0.0012,  ..., 0.0012, 0.0007, 0.0002]]]])

# %% [markdown]
# ## Next, let us see how we can freeze parameters for transfer learning

# %% [markdown]
# ### First check model parameters

# %%
net.parameters
# Out:
# <bound method Module.parameters of Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (final_conv): Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1))
#   (transpose_conv): ConvTranspose2d(21, 21, kernel_size=(64, 64), stride=(32, 32), padding=(16, 16))
# )>

# %% [markdown]
# ### Show the last two layers (to be freezed)

# %%
net[-2:].parameters
# Out:
# <bound method Module.parameters of Sequential(
#   (final_conv): Conv2d(512, 21, kernel_size=(1, 1), stride=(1, 1))
#   (transpose_conv): ConvTranspose2d(21, 21, kernel_size=(64, 64), stride=(32, 32), padding=(16, 16))
# )>

# %% [markdown]
# ### Freeze all parameters except the last two layers.

# %%
for parameter in net.parameters():
    parameter.requires_grad = False
for parameter in net[-2:].parameters():
    parameter.requires_grad = True

# %% [markdown]
# ### Let us double check to see if the correct layers have been freezed.

# %%
for name, param in net.named_parameters():
    #print(name)
    if param.requires_grad:print(name)
# Out:
# final_conv.weight
# final_conv.bias
# transpose_conv.weight
# transpose_conv.bias

# %% [markdown]
# ## Create dataloaders

# %%
batch_size, crop_size = 32, (320, 480)
train_iter, test_iter = d2l.load_data_voc(batch_size, crop_size)
# Out:
# read 1114 examples
# read 1078 examples

# %%
def loss(inputs, targets):
    return F.cross_entropy(inputs, targets, reduction='none').mean(1).mean(1)

num_epochs, lr, wd, devices = 5, 0.001, 1e-3, d2l.try_all_gpus()
trainer = torch.optim.SGD(net.parameters(), lr=lr, weight_decay=wd)
d2l.train_ch13(net, train_iter, test_iter, loss, trainer, num_epochs, devices)
# Out:
# loss 0.670, train acc 0.812, test acc 0.810
# 3.1 examples/sec on [device(type='cuda', index=0)]

# %%
def loss(inputs, targets):
    return F.cross_entropy(inputs, targets, reduction='none').mean(1).mean(1)

num_epochs, lr, wd, devices = 50, 0.001, 1e-3, d2l.try_all_gpus()
trainer = torch.optim.SGD(net.parameters(), lr=lr, weight_decay=wd)
d2l.train_ch13(net, train_iter, test_iter, loss, trainer, num_epochs, devices)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-836511348dbf> in <module>
#       4 num_epochs, lr, wd, devices = 50, 0.001, 1e-3, d2l.try_all_gpus()
#       5 trainer = torch.optim.SGD(net.parameters(), lr=lr, weight_decay=wd)
# ----> 6 d2l.train_ch13(net, train_iter, test_iter, loss, trainer, num_epochs, devices)
#
# ~\Anaconda3\envs\su\lib\site-packages\d2l\torch.py in train_ch13(net, train_iter, test_iter, loss, trainer, num_epochs, devices)
#    1587         for i, (features, labels) in enumerate(train_iter):
#    1588             timer.start()
# -> 1589             l, acc = train_batch_ch13(net, features, labels, loss, trainer,
#    1590                                       devices)
#    1591             metric.add(l, acc, labels.shape[0], labels.numel())
#
# ~\Anaconda3\envs\su\lib\site-packages\d2l\torch.py in train_batch_ch13(net, X, y, loss, trainer, devices)
#    1560         X = [x.to(devices[0]) for x in X]
#    1561     else:
# -> 1562         X = X.to(devices[0])
#    1563     y = y.to(devices[0])
#    1564     net.train()
#
# RuntimeError: CUDA error: an illegal memory access was encountered

# %% [markdown]
# ## Use the trained model to predict on the test dataset

# %%
def predict(img):
    X = test_iter.dataset.normalize_image(img).unsqueeze(0)
    pred = net(X.to(devices[0])).argmax(dim=1)
    return pred.reshape(pred.shape[1], pred.shape[2])

def label2image(pred):
    colormap = torch.tensor(d2l.VOC_COLORMAP, device=devices[0])
    X = pred.long()
    return colormap[X, :]

# %%
test_images, test_labels = d2l.read_voc_images(voc_dir, False)
n, imgs = 4, []
for i in range(n):
    crop_rect = (0, 0, 320, 480)
    X = torchvision.transforms.functional.crop(test_images[i], *crop_rect)
    pred = label2image(predict(X))
    imgs += [
        X.permute(1, 2, 0),
        pred.cpu(),
        torchvision.transforms.functional.crop(test_labels[i],
                                               *crop_rect).permute(1, 2, 0)]
d2l.show_images(imgs[::3] + imgs[1::3] + imgs[2::3], 3, n, scale=2);
